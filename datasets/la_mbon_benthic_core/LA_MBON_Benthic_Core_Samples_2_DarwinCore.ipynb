# %% [markdown]
# <a href="https://colab.research.google.com/github/MathewBiddle/bio_data_guide/blob/la_mbon_benthic_core/datasets/la_mbon_benthic_core/LA_MBON_Benthic_Core_Samples_2_DarwinCore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Get data from ERDDAP and convert to Darwin Core
#
# https://gcoos4.geos.tamu.edu/erddap/tabledap/mbon_la_2023.html
#
# https://github.com/ioos/mbon_data_workshop_2025/issues/9

# %%
# !pip install erddapy
# !pip install pyworms
# Out:
# Requirement already satisfied: erddapy in /usr/local/lib/python3.11/dist-packages (2.2.4)
# Requirement already satisfied: httpx>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from erddapy) (0.28.1)
# Requirement already satisfied: pandas<3,>=0.25.2 in /usr/local/lib/python3.11/dist-packages (from erddapy) (2.2.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from erddapy) (2025.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->erddapy) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->erddapy) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->erddapy) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->erddapy) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.25.0->erddapy) (0.16.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=0.25.2->erddapy) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=0.25.2->erddapy) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=0.25.2->erddapy) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=0.25.2->erddapy) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.25.0->erddapy) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.25.0->erddapy) (4.13.2)
# Requirement already satisfied: pyworms in /usr/local/lib/python3.11/dist-packages (0.4.0)
# Requirement already satisfied: backports.functools-lru-cache in /usr/local/lib/python3.11/dist-packages (from pyworms) (2.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pyworms) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pyworms) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pyworms) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pyworms) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pyworms) (2025.4.26)

# %% [markdown]
# ## Go get data and metadata

# %%
from erddapy import ERDDAP
import pandas as pd

server = "https://gcoos4.geos.tamu.edu/erddap/"

protocol = "tabledap"

search_for = 'sanctsound "Sound Production"'

e = ERDDAP(server=server, protocol=protocol)

e.dataset_id = "mbon_la_2023"

meta = pd.read_csv(e.get_info_url().replace('.html','.csv'))

df = e.to_pandas()

df.sample(n=5)
# Out:
#            basin site replicate  latitude (degrees_north)  \
# 201          NaN  BB1        R3                 29.390940
# 205          NaN  BB2        R1                 29.338230
# 366          NaN  AD2   R1_sub2                 29.422956
# 348          NaN  MD5        R6                 29.324260
# 170  Atchafalaya  AD3        R4                 29.490540
#
#      longitude (degrees_east)       date  time2 sample_method        weather  \
# 201                -89.924710  7/12/2023  10:43     push_core          sunny
# 205                -89.929030  7/12/2023  12:18     push_core          sunny
# 366                -91.279755   7/3/2023  13:43     push_core  partly_cloudy
# 348                -89.403500  7/16/2023  16:20     push_core          sunny
# 170                -91.339640  4/14/2023  13:25     push_core          sunny
#
#      wind (knots)  ...  Amphioplus_sp (count)  Microphiopholis_atra (count)  \
# 201             4  ...                      0                             0
# 205             2  ...                      0                             1
# 366             1  ...                      0                             0
# 348             1  ...                      0                             0
# 170             1  ...                      0                             0
#
#      Pentamera_pulcherrima (count)  Cnidaria (count)  Anemone (count)  \
# 201                              0                 0                0
# 205                              0                 0                0
# 366                              0                 0                0
# 348                              0                 0                0
# 170                              0                 0                0
#
#      Leech (count)  Bug (count) Ephemeroptera_sp (count) Eel (count)  \
# 201              0            0                        0           0
# 205              0            0                        0           0
# 366              0            0                        0           0
# 348              0            0                        0           0
# 170              0            0                        0           0
#
#      Copepod (count)
# 201                0
# 205                0
# 366                0
# 348                0
# 170                0
#
# [5 rows x 123 columns]

# %%
meta.sample(n=5)
# Out:
#       Row Type       Variable Name Attribute Name Data Type              Value
# 161  attribute               depth  standard_name    String              depth
# 427  attribute  Leiocapitella_sp_B          units    String              count
# 365   variable  Polydora_aggregata            NaN       int                NaN
# 411  attribute   Notomastus_daueri      long_name    String  Notomastus Daueri
# 861  attribute             Anemone  ioos_category    String            Unknown

# %% [markdown]
# # convert wide to long format
#
# Right now, species are in the column headers. We need to make a row for each species.

# %%
non_species = [col for col in df.columns if "(count)" not in str(col)]

df_melt = pd.melt(df, id_vars=non_species, var_name='species')

df_melt.sample(n=5)
# Out:
#             basin site replicate  latitude (degrees_north)  \
# 1707   Terrebonne  TB6        R3                  29.31804
# 38696         NaN  BB4        R1                  29.29560
# 21528  Terrebonne  TB1        R3                  29.25336
# 13979         NaN  BB2        R3                  29.33185
# 13772   Barataria  BB1   R1_sub3                  29.39825
#
#        longitude (degrees_east)       date  time2 sample_method  \
# 1707                  -90.34680  4/10/2023  10:22     push_core
# 38696                 -89.91075  7/12/2023  13:11     push_core
# 21528                 -90.66844  4/15/2023   0:00     push_core
# 13979                 -89.92684  7/12/2023  12:00     push_core
# 13772                 -89.92838  4/20/2023  11:04     push_core
#
#              weather  wind (knots)  ...    pH  temp (degrees Celsius)  \
# 1707   partly_cloudy             4  ...  7.91                  21.327
# 38696  partly_cloudy             2  ...  7.99                  31.090
# 21528  mostly_cloudy             2  ...  7.82                  26.895
# 13979          sunny             3  ...  7.93                  30.620
# 13772          sunny             4  ...  8.36                  22.003
#
#        sal (psu)  bott_chlor (ug/L)  surf_chlor (ug/L)  depth (m)  sediment  \
# 1707       19.88              11.41              11.77    2.10312      clay
# 38696      30.20              16.11               7.61    0.91440      clay
# 21528      17.34              23.58              26.19    1.06680     muddy
# 13979      31.18               7.51              10.00    2.19456     sandy
# 13772      12.76              20.88              18.75    2.43840     muddy
#
#       high_organic                       species value
# 1707            no         Tellinidae_sp (count)   0.0
# 38696           no  Microphiopholis_atra (count)   0.0
# 21528           no         Magelona_sp_I (count)   0.0
# 13979           no     Notomastus_daueri (count)   0.0
# 13772           no     Notomastus_daueri (count)   0.0
#
# [5 rows x 21 columns]

# %% [markdown]
# # only find where species was observed
#
# We don't care about the value=0 data

# %%
df_melt = df_melt.loc[df_melt['value']>0]

df_melt.sample(n=5)
# Out:
#              basin site replicate  latitude (degrees_north)  \
# 8386           NaN  TB6   R1_sub2                  29.31097
# 3325    Terrebonne  TB6        R1                  29.31097
# 10413          NaN  TB6        R2                  29.31559
# 16609    Barataria  BB1        R3                  29.39094
# 8667   Atchafalaya  AD2        R4                  29.42220
#
#        longitude (degrees_east)       date  time2 sample_method  \
# 8386                  -90.34413   7/5/2023  13:18     push_core
# 3325                  -90.34413  4/10/2023  10:30     push_core
# 10413                 -90.33950   7/5/2023  13:01    ponar_grab
# 16609                 -89.92471  4/20/2023  10:59    ponar_grab
# 8667                  -91.28162  4/14/2023  11:25     push_core
#
#              weather  wind (knots)  ...    pH  temp (degrees Celsius)  \
# 8386   partly_cloudy             1  ...  7.84                  32.170
# 3325   partly_cloudy             4  ...  7.93                  21.268
# 10413  partly_cloudy             1  ...  7.85                  31.980
# 16609          sunny             4  ...  8.37                  21.974
# 8667           sunny             1  ...  7.67                  17.927
#
#        sal (psu)  bott_chlor (ug/L)  surf_chlor (ug/L)  depth (m)  sediment  \
# 8386       21.81              24.08              23.13    1.40000     muddy
# 3325       19.75               4.40              12.85    1.98120      clay
# 10413      21.64              24.20              18.25    2.00000    shelly
# 16609      13.44              23.68              20.94    2.40790     sandy
# 8667        0.10               5.60               4.52    1.88976     silty
#
#       high_organic                          species value
# 8386           yes        Arcuatula_papyria (count)   2.0
# 3325            no  Austromacoma_constricta (count)   1.0
# 10413           no    Manayunkia_aestuarina (count)   2.0
# 16609           no       Glycinde_multidens (count)   5.0
# 8667            no          Alitta_succinea (count)   1.0
#
# [5 rows x 21 columns]

# %% [markdown]
# Clean up the species names

# %%
df_melt['species'] = df_melt['species'].str.replace(" (count)","")

df_melt['species'].unique()
# Out:
# array(['Nemerteans', 'Oligochaetes', 'Chironomidae_sp', 'Bivalve',
#        'Tellinidae_sp', 'Ameritella_versicolor', 'Psammotreta_brevifrons',
#        'Macoploma_tenta', 'Austromacoma_constricta', 'Mulinia_lateralis',
#        'Spisula_raveneli', 'Rangia_sp', 'Rangia_cuneata',
#        'Dosinia_discus', 'Agriopoma_texasianum',
#        'Mercenaria_campechiensis', 'Tagelus_divisus',
#        'Kelliopsis_elevata', 'Nuculana_concentrica', 'Ensis_minor',
#        'Arcuatula_papyria', 'Alitta_succinea', 'Nereis_splendida',
#        'Ceratocephale_oculata', 'Kirkegaardia_annulosa',
#        'Manayunkia_aestuarina', 'Acromegalomma_bioculatum',
#        'Paraprionospio_pinnata', 'Polydora_aggregata', 'Dispio_uncinata',
#        'Boccardiella_sp_A', 'Capitellidae_sp', 'Mediomastus_ambiseta',
#        'Capitella_capitata', 'Notomastus_daueri', 'Decamastus_gracilis',
#        'Leiocapitella_sp_B', 'Mediomastus_californiensis',
#        'Synelmis_albini', 'Hermundura_americana', 'Sigambra_tentaculata',
#        'Glycinde_multidens', 'Glycera_sp', 'Goniada_maculata',
#        'Goniada_teres', 'Glycinde_nordmanni', 'Glycera_robusta',
#        'Glycera_americana', 'Diopatra_cuprea', 'Leitoscoloplos_fragilis',
#        'Phylo_felix', 'Naineris_laevigata', 'Magelona_uebelackerae',
#        'Magelona_sp_I', 'Allia_quadrilobata', 'Cirrophorus_forticirratus',
#        'Allia_trilobata', 'Cossura_soyeri', 'Melinna_cristata',
#        'Hobsonia_florida', 'Ampharete_sp_B', 'Podarkeopsis_sp',
#        'Podarkeopsis_brevipalpa', 'Lumbrineris_ernesti',
#        'Clymnella_torquata', 'Amphictene_helenae', 'Malmgreniella_sp_A',
#        'Mystides_borealis', 'Eteone_lactea', 'Arabellidae_sp',
#        'Apocorophium_louisianum', 'Gammaridae_sp', 'Gammarus_mucronatus',
#        'Megaluropidae_sp', 'Haustoriidae_sp', 'Ampelisa_abdita',
#        'Eusiridae_sp', 'Edotia_montosa', 'Cyathura_polita',
#        'Alpheus_heterochaelis', 'Automate_sp', 'Mysidae_sp',
#        'Mysidopsis_sp', 'Ogyrides_alphaerostris', 'Cumaceae_sp',
#        'Pagurus_sp', 'Pagurus_bullisi', 'Clibanarius_vittatus',
#        'Panopeidae_sp', 'Hexapanopeus_angustifrons', 'Oliva_sayana',
#        'Nassarius_acutus', 'Neverita_duplicata', 'Neritina_usnea',
#        'Amphioplus_sp', 'Microphiopholis_atra', 'Pentamera_pulcherrima',
#        'Cnidaria', 'Anemone', 'Leech', 'Bug', 'Ephemeroptera_sp', 'Eel',
#        'Copepod'], dtype=object)

# %% [markdown]
# Now we need to build a mapping table to WoRMS identification.
#
# For names that have matches != 1, need to do some human deciding.

# %%
import pyworms

df_worms_mapping = dict()

for species in df_melt['species'].unique():
  worms_info = pyworms.aphiaRecordsByMatchNames(species, marine_only=True)
  df_worms_mapping[species] = worms_info[0]

  if len(worms_info[0]) != 1:
    print(f'Found {len(worms_info[0])} matches for {species}')
# Out:
# Found 3 matches for Nemerteans
# Found 0 matches for Oligochaetes
# Found 0 matches for Bivalve
# Found 2 matches for Ensis_minor
# Found 3 matches for Nereis_splendida
# Found 2 matches for Glycera_sp
# Found 0 matches for Allia_quadrilobata
# Found 0 matches for Allia_trilobata
# Found 0 matches for Cumaceae_sp
# Found 0 matches for Leech
# Found 0 matches for Bug
# Found 0 matches for Ephemeroptera_sp
# Found 0 matches for Eel
# Found 0 matches for Copepod

# %% [markdown]
# Need to figure out what to do with those. First, insert the species information we know.

# %%
for species in df_worms_mapping:
  if len(df_worms_mapping[species])==1:
    df_melt.loc[df_melt['species']==species,'kingdom'] = df_worms_mapping[species][0]['kingdom']
    df_melt.loc[df_melt['species']==species,'scientificName'] = df_worms_mapping[species][0]['scientificname']
    df_melt.loc[df_melt['species']==species,'scientificNameID'] = df_worms_mapping[species][0]['lsid']
df_melt.sample(n=5)
# Out:
#             basin site replicate  latitude (degrees_north)  \
# 14436         NaN  TB3        R1                 29.059600
# 28742         NaN  AD5        R2                 29.619553
# 261           NaN  TB3        R1                 29.059600
# 33002         NaN  BB1        R1                 29.398250
# 11016  Terrebonne  TB5        R5                 29.152510
#
#        longitude (degrees_east)       date  time2 sample_method  \
# 14436                 -90.72260   7/4/2023  11:56     push_core
# 28742                 -91.32493   7/3/2023   9:19    ponar_grab
# 261                   -90.72260   7/4/2023  11:56     push_core
# 33002                 -89.92838  7/12/2023  11:01     push_core
# 11016                 -90.20687  4/10/2023  12:11     push_core
#
#              weather  wind (knots)  ...  bott_chlor (ug/L)  surf_chlor (ug/L)  \
# 14436  partly_cloudy             1  ...               8.48               6.38
# 28742  partly_cloudy             1  ...               7.56               7.99
# 261    partly_cloudy             1  ...               8.48               6.38
# 33002          sunny             4  ...              12.98               9.32
# 11016  partly_cloudy             4  ...              16.83               5.78
#
#        depth (m)  sediment  high_organic                  species  value  \
# 14436     3.2000     muddy            no      Decamastus_gracilis    1.0
# 28742     5.1816  detritus            no  Apocorophium_louisianum   41.0
# 261       3.2000     muddy            no               Nemerteans    8.0
# 33002     2.1336      clay            no               Mysidae_sp    1.0
# 11016     0.6096      clay            no   Paraprionospio_pinnata    5.0
#
#         kingdom           scientificName  \
# 14436  Animalia      Decamastus gracilis
# 28742  Animalia  Apocorophium louisianum
# 261         NaN                      NaN
# 33002  Animalia                  Mysidae
# 11016  Animalia   Paraprionospio pinnata
#
#                                 scientificNameID
# 14436  urn:lsid:marinespecies.org:taxname:326885
# 28742  urn:lsid:marinespecies.org:taxname:421575
# 261                                          NaN
# 33002  urn:lsid:marinespecies.org:taxname:119822
# 11016  urn:lsid:marinespecies.org:taxname:131140
#
# [5 rows x 24 columns]

# %% [markdown]
# What to do with the stuff we don't know??

# %%
df_melt.loc[df_melt['species']=='Bug']
# Out:
#            basin site replicate  latitude (degrees_north)  \
# 40532  Barataria  BB5        R1                 29.287510
# 40732        NaN  BB5        R2                 29.288790
# 40782        NaN  TB5        R4                 29.156240
# 40885        NaN  AD4        R3                 29.634586
# 40904        NaN  AD6        R6                 29.553507
#
#        longitude (degrees_east)       date  time2 sample_method  \
# 40532                -90.004760  4/26/2023  14:01    ponar_grab
# 40732                -89.998300  7/12/2023  14:30     push_core
# 40782                -90.209210   7/5/2023  10:44     push_core
# 40885                -91.260570   7/3/2023  16:41     push_core
# 40904                -91.325264   7/3/2023  10:20    ponar_grab
#
#              weather  wind (knots)  ...  bott_chlor (ug/L)  surf_chlor (ug/L)  \
# 40532          sunny             3  ...              19.27              15.68
# 40732         cloudy             3  ...              14.81              14.97
# 40782         cloudy             1  ...              10.42              11.89
# 40885          sunny             1  ...              14.11              16.49
# 40904  partly_cloudy             1  ...               3.60              10.85
#
#        depth (m)  sediment  high_organic  species  value kingdom  \
# 40532    2.37744     muddy            no      Bug    1.0     NaN
# 40732    1.52400      clay            no      Bug    1.0     NaN
# 40782    0.90000     muddy            no      Bug    1.0     NaN
# 40885    0.60960     muddy            no      Bug    1.0     NaN
# 40904    5.18160     muddy            no      Bug    1.0     NaN
#
#       scientificName scientificNameID
# 40532            NaN              NaN
# 40732            NaN              NaN
# 40782            NaN              NaN
# 40885            NaN              NaN
# 40904            NaN              NaN
#
# [5 rows x 24 columns]
